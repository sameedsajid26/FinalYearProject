# %%
import numpy as np

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
df_labels = pd.read_csv('new_labels.txt')

# %%
df_labels.head()
# Out:
#    -177.768868661742
# 0        -178.233750
# 1        -175.997819
# 2        -208.002438
# 3        -191.537486
# 4        -180.577547

# %%
print(df_labels.describe())
# Out:
#        -177.768868661742
# count        1999.000000
# mean         -184.528511
# std            10.546235
# min          -219.504144
# 25%          -191.737816
# 50%          -184.574542
# 75%          -177.392426
# max          -143.672654

# %%
plt.figure(figsize=(9, 8))
sns.distplot(df_labels, color='b', bins=100, hist_kws={'alpha': 0.4});
# Out:
# /var/folders/tp/zxff3h0n1l321mt9pq12m2gr0000gn/T/ipykernel_5577/383320334.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_labels, color='b', bins=100, hist_kws={'alpha': 0.4});

# %%
plt.figure(figsize=(9, 8))
sns.displot(df_labels, color='b', bins=100, kde=True,legend=False);

# %%
#PCA analysis:
from sklearn.decomposition import IncrementalPCA
from sklearn.decomposition import PCA
import numpy as np

x_data = np.loadtxt('new_x_data.txt')
x_data.reshape(-1,1)


pca = PCA().fit(x_data)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
import numpy as np

np.loadtxt('x2000_data_after_PCA.txt').shape
# Out:
# (2000, 314)

# %%
np.loadtxt('x_train.txt').shape
# Out:
# (3000, 626)

# %%
import pandas as pd

loss = pd.read_csv('checkpoint/log/model_0-4_layer-80_80_80_80_nodes.acc.loss',sep = '\s+')

loss
# Out:
#      epoch   train_mae    val_mae       mape   val_mape       loss   val_loss
# 0        0  129.309448  35.792660  70.125633  19.318911  73.714050  23.187559
# 1        1   27.029905  16.234585  14.678363   8.752433  18.444233  12.429790
# 2        2   19.758978  14.424461  10.713318   7.801690  14.303327  11.314924
# 3        3   17.699291  12.683560   9.580838   6.842625  13.032330  10.250150
# 4        4   16.222416  12.289185   8.820335   6.550057  12.190106   9.869660
# ..     ...         ...        ...        ...        ...        ...        ...
# 495    495    7.063781  10.597286   3.827948   5.727135   4.467093   6.362904
# 496    496    6.814540  10.287612   3.688831   5.580275   4.328867   6.221837
# 497    497    7.084514  11.052213   3.848744   5.961146   4.487689   6.595468
# 498    498    7.055346  10.428965   3.823262   5.635191   4.457933   6.263159
# 499    499    7.137002  10.513139   3.870939   5.709604   4.499241   6.333215
#
# [500 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import matplotlib.pyplot as plt

loss.plot(x='epoch', y=['mape', 'val_mape'])
plt.legend(labels=["MAPE", "Validation MAPE"])
plt.show()
